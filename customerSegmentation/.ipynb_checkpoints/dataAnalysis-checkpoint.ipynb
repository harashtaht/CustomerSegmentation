# %% [markdown]
# ## Customer Segmentation for Automobile Company

# %% [markdown]
# <u>Context</u>
#
# An automobile company has plans to enter new markets with their existing products (P1, P2, P3, P4 and P5). After intensive market research, they’ve deduced that the behavior of new market is similar to their existing market.
#
# <u>Content</u>
#
# In their existing market, the sales team has classified all customers into 4 segments (A, B, C, D ). Then, they performed segmented outreach and communication for different segment of customers. This strategy has work exceptionally well for them. They plan to use the same strategy on new markets and have identified 2627 new potential customers.
#
# You are required to help the manager to predict the right group of the new customers.
#
# Acknowledgements
#
# https://datahack.analyticsvidhya.com/contest/janatahack-customer-segmentation/#ProblemStatement
#
# Inspiration
#
# https://datahack.analyticsvidhya.com/contest/janatahack-customer-segmentation/#ProblemStatement
#
# Dataset Source
#
# https://www.kaggle.com/vetrirah/customer

# %% [markdown]
# ### __1. Importing Data__
#
# The first step in building the model is to importing Libraries and understanding features within the unprocessed dataset.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# __a. Sample Submission Data__

# %%
df1 = pd.read_csv('./Files/sample_submission.csv')
df1.head()
# Out:
#        ID Segmentation
# 0  458989            A
# 1  458994            A
# 2  458996            A
# 3  459000            A
# 4  459001            A

# %%
listItem = []
for col in df1.columns:
    listItem.append([col, df1[col].dtype,
                   df1[col].isna().sum(),
                   round((df1[col].isna().sum()/len(df1[col])) *100, 2),
                   df1[col].nunique(), list(df1[col].unique()[:5])]);

df1Desc = pd.DataFrame(columns=['dataFeatures', 'dataType', 'null', 'nullPct', 'unique', 'uniqueSample'],
                     data=listItem)

df1Desc
# Out:
#    dataFeatures dataType  null  nullPct  unique  \
# 0            ID    int64     0      0.0    2627
# 1  Segmentation   object     0      0.0       1
#
#                                uniqueSample
# 0  [458989, 458994, 458996, 459000, 459001]
# 1                                       [A]

# %%
df1.describe().T
# Out:
#      count           mean          std       min       25%       50%  \
# ID  2627.0  463433.918919  2618.245698  458989.0  461162.5  463379.0
#
#          75%       max
# ID  465696.0  467968.0

# %% [markdown]
# __b. Train and Test Data__
#
# Columns Explanation:
#
# - Work_Experience = customer's work experience in Years.
# - Graduated = indication whether the customer has graduated.
# - Family_Size = Number of family members including the customer.
# - Spending_Score = Spending score of the customer.
# - Var_1 = Anonymised Category for the customer.
# - Segmentation = (target) Customer Segment of the Customer.

# %% [markdown]
# Dataframe preparation

# %%
dfTr = pd.read_csv('./Files/Train.csv')
dfTr.head()
# Out:
#        ID  Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# 0  462809    Male           No   22        No     Healthcare              1.0
# 1  462643  Female          Yes   38       Yes       Engineer              NaN
# 2  466315  Female          Yes   67       Yes       Engineer              1.0
# 3  461735    Male          Yes   67       Yes         Lawyer              0.0
# 4  462669  Female          Yes   40       Yes  Entertainment              NaN
#
#   Spending_Score  Family_Size  Var_1 Segmentation
# 0            Low          4.0  Cat_4            D
# 1        Average          3.0  Cat_4            A
# 2            Low          1.0  Cat_6            B
# 3           High          2.0  Cat_6            B
# 4           High          6.0  Cat_6            A

# %%
dfTs = pd.read_csv('./Files/Test.csv')
dfTs.head()
# Out:
#        ID  Gender Ever_Married  Age Graduated  Profession  Work_Experience  \
# 0  458989  Female          Yes   36       Yes    Engineer              0.0
# 1  458994    Male          Yes   37       Yes  Healthcare              8.0
# 2  458996  Female          Yes   69        No         NaN              0.0
# 3  459000    Male          Yes   59        No   Executive             11.0
# 4  459001  Female           No   19        No   Marketing              NaN
#
#   Spending_Score  Family_Size  Var_1
# 0            Low          1.0  Cat_6
# 1        Average          4.0  Cat_6
# 2            Low          1.0  Cat_6
# 3           High          2.0  Cat_6
# 4            Low          4.0  Cat_6

# %%
print(dfTr.shape)
print(dfTs.shape)
# Out:
# (8068, 11)
# (2627, 10)

# %% [markdown]
# Comments:
#
# - The train data has 8068 rows, and 11 columns.
# - Whereas the test data consists of 2627 rows and 10 columns.
# - The test data has 1 less column, which is due to "Segmentation" being the target.
# - Thus, the ratio of train to test data is 3:1 which is quite good for the model. 24.5% of the whole data available for the model training.

# %% [markdown]
# __c. Dataframe Information__

# %% [markdown]
# __c.1. Train Dataframe__

# %%
#Function to describe Dataframe

def describeDF(x):
    listItem = []
    for col in x.columns:
        listItem.append([col, x[col].dtype,
                       x[col].isna().sum(),
                       round((x[col].isna().sum()/len(x[col])) *100, 2),
                       x[col].nunique(), list(x[col].unique()[:5])]);

    desc = pd.DataFrame(columns=['dataFeatures', 'dataType', 'null', 'nullPct', 'unique', 'uniqueSample'],
                         data=listItem)
    return desc

# %%
describeDF(dfTr)
# Out:
#        dataFeatures dataType  null  nullPct  unique  \
# 0                ID    int64     0     0.00    8068
# 1            Gender   object     0     0.00       2
# 2      Ever_Married   object   140     1.74       2
# 3               Age    int64     0     0.00      67
# 4         Graduated   object    78     0.97       2
# 5        Profession   object   124     1.54       9
# 6   Work_Experience  float64   829    10.28      15
# 7    Spending_Score   object     0     0.00       3
# 8       Family_Size  float64   335     4.15       9
# 9             Var_1   object    76     0.94       7
# 10     Segmentation   object     0     0.00       4
#
#                                          uniqueSample
# 0            [462809, 462643, 466315, 461735, 462669]
# 1                                      [Male, Female]
# 2                                      [No, Yes, nan]
# 3                                [22, 38, 67, 40, 56]
# 4                                      [No, Yes, nan]
# 5   [Healthcare, Engineer, Lawyer, Entertainment, ...
# 6                           [1.0, nan, 0.0, 4.0, 9.0]
# 7                                [Low, Average, High]
# 8                           [4.0, 3.0, 1.0, 2.0, 6.0]
# 9                 [Cat_4, Cat_6, Cat_7, Cat_3, Cat_1]
# 10                                       [D, A, B, C]

# %%
dfTr.describe().T
# Out:
#                   count           mean          std       min        25%  \
# ID               8068.0  463479.214551  2595.381232  458982.0  461240.75
# Age              8068.0      43.466906    16.711696      18.0      30.00
# Work_Experience  7239.0       2.641663     3.406763       0.0       0.00
# Family_Size      7733.0       2.850123     1.531413       1.0       2.00
#
#                       50%        75%       max
# ID               463472.5  465744.25  467974.0
# Age                  40.0      53.00      89.0
# Work_Experience       1.0       4.00      14.0
# Family_Size           3.0       4.00       9.0

# %% [markdown]
# Comments:
#
# - There are a very high percentage of null value (10.28%) in Work_Experience which might affect the model later on. This is perhaps due to the unwillingness of customer to state their job, or they are still looking for a steady job.
# - Family_Size has 4.15 % of null value, meaning that some user prefer to keep their privacy.
# - Ever_Married, Profession, Graduated and Var_1 both have less than 2% of null value.
# - Must consider what to do with the null value, since it might affect the model performance.
#
# __more comments on the statistic distribution__

# %% [markdown]
# __c.2. Test Dataframe__

# %%
describeDF(dfTs)
# Out:
#       dataFeatures dataType  null  nullPct  unique  \
# 0               ID    int64     0     0.00    2627
# 1           Gender   object     0     0.00       2
# 2     Ever_Married   object    50     1.90       2
# 3              Age    int64     0     0.00      67
# 4        Graduated   object    24     0.91       2
# 5       Profession   object    38     1.45       9
# 6  Work_Experience  float64   269    10.24      15
# 7   Spending_Score   object     0     0.00       3
# 8      Family_Size  float64   113     4.30       9
# 9            Var_1   object    32     1.22       7
#
#                                         uniqueSample
# 0           [458989, 458994, 458996, 459000, 459001]
# 1                                     [Female, Male]
# 2                                     [Yes, No, nan]
# 3                               [36, 37, 69, 59, 19]
# 4                                     [Yes, No, nan]
# 5  [Engineer, Healthcare, nan, Executive, Marketing]
# 6                         [0.0, 8.0, 11.0, nan, 5.0]
# 7                               [Low, Average, High]
# 8                          [1.0, 4.0, 2.0, 5.0, 3.0]
# 9                  [Cat_6, Cat_4, Cat_3, nan, Cat_1]

# %%
dfTs.describe().T
# Out:
#                   count           mean          std       min       25%  \
# ID               2627.0  463433.918919  2618.245698  458989.0  461162.5
# Age              2627.0      43.649791    16.967015      18.0      30.0
# Work_Experience  2358.0       2.552587     3.341094       0.0       0.0
# Family_Size      2514.0       2.825378     1.551906       1.0       2.0
#
#                       50%       75%       max
# ID               463379.0  465696.0  467968.0
# Age                  41.0      53.0      89.0
# Work_Experience       1.0       4.0      14.0
# Family_Size           2.0       4.0       9.0

# %% [markdown]
# Comments:
# - The test data is also filled with most null data in Work_Experience, which means this might be quite an important feature in determining the Segmentation.
# - Overall, the features with most null values are also similar with the train data.

# %% [markdown]
# ### __2. Exploratory Data Analysis (EDA)__

# %% [markdown]
# __A. Data Analization and Visualization__

# %% [markdown]
# Based on the high percentage of null values in Train Data, columns that contain null values in order are as follow (including the datatypes):
#
# 1. Work_Experience - 10.28% - float64
# 2. Family_Size - 4.15% - float64
# 3. Ever_Married - 1.74% - object
# 4. Profession - 1.54% - object
# 5. Graduated - 0.97% - object
# 6. Var_1 - 0.94% - object
#
# - The top 2 null percentages are numerical data, whereas the others are categorical data.
#
# - Although the percentages are different within the Test Data, the patterns are quite similar. So, let's explore these data first to figure out what methods will be used to handle the null values.

# %%
sns.countplot(dfTr['Segmentation'])

# %% [markdown]
# __A.1. Work Experience and Family Size Influence on the Segmentation__

# %%
# Duplicate Train Data to Modify without changing the initial value
trMod = dfTr.copy(deep=True)

# Encoding the Segmentation Columns categorical data into numerical to ease the analysation
trMod['Segmentation'] = trMod['Segmentation'].apply(lambda val: 1 if val=='A' 
                                                    else(2 if val=='B' 
                                                         else(3 if val=='C' else 4)))

# %%
plt.figure(figsize=(16,8))

plt.subplot(2,2,1)
sns.kdeplot(trMod[trMod['Segmentation'] == 1]['Work_Experience'].dropna(), label = 'A')
sns.kdeplot(trMod[trMod['Segmentation'] == 2]['Work_Experience'].dropna(), label = 'B')
sns.kdeplot(trMod[trMod['Segmentation'] == 3]['Work_Experience'].dropna(), label = 'C')
sns.kdeplot(trMod[trMod['Segmentation'] == 4]['Work_Experience'].dropna(), label = 'D')
plt.grid(True)

plt.subplot(2,2,2)
sns.kdeplot(trMod[trMod['Segmentation'] == 1]['Family_Size'].dropna(), label = 'A')
sns.kdeplot(trMod[trMod['Segmentation'] == 2]['Family_Size'].dropna(), label = 'B')
sns.kdeplot(trMod[trMod['Segmentation'] == 3]['Family_Size'].dropna(), label = 'C')
sns.kdeplot(trMod[trMod['Segmentation'] == 4]['Family_Size'].dropna(), label = 'D')
plt.grid(True)


plt.subplot(2,2,3)
sns.countplot(trMod['Work_Experience'].dropna())

plt.subplot(2,2,4)
sns.countplot(trMod['Family_Size'])

# %% [markdown]
# - On the plot for Work_Experience, it can be seen that the patterns are quite similar between each Segmentation. The peak can be seen the most within the 0 and 1 value, then it is constant until the value 8 and 9. From 10 to the rest, is quite a low count.
#
# - In Family_Size plot, it can be seen that Segmentation C has the lowest user number in Family_Size of 1 compare to the other Segmentations. However, in the highest frequency of Family_Size which is 2, it can be seen that Segmentation C has the most user. A high frequency of Segmentation A seems to be found in Family Size of 1, whereas it's the lowest in Family_Size of 4.
#
# - From this, we can conclude that perhaps the feature Family_Size has a certain influence towards the Segmentations. Whereas the Work_Experience doesn't contribute as significant as Family_Size. However, we must evaluate more to confirm this hypothesis.

# %% [markdown]
# __A.2. Numerical Data Influences Toward Segmentation__

# %%
# Duplicating Training Data, and labeling the target columns with One Hot Encoder

oneHot1 = dfTr.copy(deep=True)
oneHot1['Segmentation'] = pd.Categorical(oneHot1['Segmentation'])
dfDummies = pd.get_dummies(oneHot1['Segmentation'], prefix = 'Segm')
oneHot2 = pd.concat([oneHot1, dfDummies], axis=1).drop('Segmentation',
                                                       axis = 1)
oneHot2.head()
# Out:
#        ID  Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# 0  462809    Male           No   22        No     Healthcare              1.0
# 1  462643  Female          Yes   38       Yes       Engineer              NaN
# 2  466315  Female          Yes   67       Yes       Engineer              1.0
# 3  461735    Male          Yes   67       Yes         Lawyer              0.0
# 4  462669  Female          Yes   40       Yes  Entertainment              NaN
#
#   Spending_Score  Family_Size  Var_1  Segm_A  Segm_B  Segm_C  Segm_D
# 0            Low          4.0  Cat_4       0       0       0       1
# 1        Average          3.0  Cat_4       1       0       0       0
# 2            Low          1.0  Cat_6       0       1       0       0
# 3           High          2.0  Cat_6       0       1       0       0
# 4           High          6.0  Cat_6       1       0       0       0

# %%
plt.figure(figsize = (18,8))

plt.subplot(1,2,1)
plt.title('Correlation of Columns Without Encoding Segmentation')
sns.heatmap(trMod.corr(), annot=True)

plt.subplot(1,2,2)
plt.title('Correlation of Columns After Encoding')
sns.heatmap(oneHot2.corr(), annot=True)

# %% [markdown]
# #### Comments
#
# __1. Correlation Before Encoding the Segmentation Columns (Left)__
#
# - The higher the Family_Size, the more tendency for the customer to be in the higher segmentation (either C or D).
# - The lower the Family_Size, more tendency of user to be in Segmentation A or B.
# - Work_Experience seems to influence only a little on the segmentation, but we found out that there is 1.3% of tendency towards Segmentation D if the Work_Experience is of a higher value.
# - The younger the customer (Age) seems to have more tendency to be in Segmentation A or B. The influence is quite high, which is 24%.
#
# __2. Correlation After Encoding the Segmentation Columns (Right)__
#
# - Segmentation A seems to be influenced the most by Family_Size(-15%). The lower the Family_Size, the more tendency of users to be segmented there. Whereas the higher the Family_Size, the more tendency towards Segmentation D (15%). Segmentation C is only affected by 4.7%, whereas Segmentation B is affected by -5.5% whenever Family_Size increases.
# - Age has quite a significant influence towards Segmentation. The higher the age, the less tendency to be in Segmentation D (-38%), whereas the older customers tend to be divided in Segmentation B (15%) and C (19%). The younger customers probably tend to be in Segmentation A and D.
# - The more Work_Experience, the more tendency towards Segmentation A and B (3.9% and 6.8%). However, it seems like it's not that impactful as Age.
#
# __Notes__
# - However, this correlation is based on only simulating the numerical value. We have to investigate further whether the other 6 columns have more influence towards the Segmentation.
# - Also to be noted, the data used has null values in Working_Experience (10%) and Family_Size (4.15%) which may affect the correlation too.

# %% [markdown]
# __A.3. Categorical Data__

# %% [markdown]
# - The data has 11 columns, which are 'ID', 'Gender', 'Ever_Married', 'Age', 'Graduated', 'Profession',
#        'Work_Experience', 'Spending_Score', 'Family_Size', 'Var_1', 'Segmentation'.
# - Since 'Segmentation' is the target for the model, we exclude it. Same as 'ID', since it's not really the customer's preferences or historical data.
# - 5 out of 9 columns are categorical, so before encoding and filling the null values, we have to analyze further into it.

# %%
plt.figure(figsize=(16,8))

plt.subplot(2,2,1)
sns.countplot(trMod['Ever_Married'].dropna())

plt.subplot(2,2,2)
sns.countplot(trMod['Profession'].dropna())

plt.subplot(2,2,3)
sns.countplot(trMod['Graduated'].dropna())

plt.subplot(2,2,4)
sns.countplot(trMod['Var_1'].dropna())

# %% [markdown]
# From the bar plots above, we can see that most of the data lies in the Customers that have/Ever_Married. Also, 62.2% of the Customers have graduated where the rest 37.8% haven't.
#
# Most of the Customers seems to have Profession as an Artist (2516), then followed by Healthcare (1332). The third among this is customers who works in Entertainment industry (949), followed by Enginer (688), Doctor (623), and Lawyer (599). The rest is in Marketing and Homemaker industry.
#
# From the anonymised data, which is 'Var_1', we can see that most Customers are in Cat_6 (5238) tremendously, followed by Cat_4 (1089) and Cat_3 (822). The least customers are in Cat_1 and Cat_5. Perhaps this Var_1 has quite a great influence towards the Customer Segmentation.
#
# To see further into this, let's break it down one by one.

# %%
def plotting(y_, hue_, data_):
    g = sns.catplot(y=y_, hue=hue_, kind="count",
                palette ="Set2", data=data_, 
                height=6, aspect=11.7/9)

    plt.title(f'Distribution of {hue_} in Terms of {y_}')
    plt.xlabel("Frequency")

    total = len(trMod["Segmentation"])
    for ax in g.axes.ravel():
        for p in ax.patches:
            percentage = '{:.1f}%'.format(100 * p.get_width()/total)
            x = p.get_x() + p.get_width() + 0.04
            y = p.get_y() + p.get_height()/2
            ax.annotate(percentage, (x, y))
    plt.grid(True)

# %% [markdown]
# __I. Ever_Married__

# %%
g = sns.catplot(y="Segmentation", hue="Ever_Married", kind="count",
            palette ="Set2", data=trMod, 
            height=6, aspect=11.7/9)

plt.title('Distribution of Segmentations in Terms of Marriage')
plt.xlabel("Frequency")

total = len(trMod["Segmentation"])
for ax in g.axes.ravel():
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.04
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))
plt.grid(True)

# %% [markdown]
# __Comments on Ever_Married Distribution__
#
# There are 140 null data, which contributes to 1.74% of the overall data.
# The values are either 'Yes' or 'No'.
#
# - In Segmentation A, B, and C, most of the customers are married.
# - In Segmentation A, there is only 4.2% difference between the "Yes" (14.1%) and "No" (9.9%).
# - In Segmentation B, the difference are quite significant, where the "Yes" is almost 3 times of the "No".
# - Segmentation C seems to have the most significance, the difference between the "Yes" values are almost 4 times of the "No" values.
# - Segmentation D seems to be the one very different, where most the customers are not married (19.9%). Also, of all the 8 segmentations, the most numbers can be found in Segmentation D Ever_Married "No".
# - The top 3 are Segmentation D "No", Segmentation C "Yes", and Segmentation B "No" with the numbers of 19.9%, 19.2% and 16.7% respectively.

# %%
# Change the value of Ever_Married into number
# X_ will be the final target for the simulation
# For the moment, the null value will be filled with "-1".

X_ = dfTr.copy(deep=True)
X_['Ever_Married'] = X_['Ever_Married'].apply(lambda val: 1 if val == 'Yes' else (0 if val == 'No' else -1))
X_.head()
# Out:
#        ID  Gender  Ever_Married  Age Graduated     Profession  \
# 0  462809    Male             0   22        No     Healthcare
# 1  462643  Female             1   38       Yes       Engineer
# 2  466315  Female             1   67       Yes       Engineer
# 3  461735    Male             1   67       Yes         Lawyer
# 4  462669  Female             1   40       Yes  Entertainment
#
#    Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0              1.0            Low          4.0  Cat_4            D
# 1              NaN        Average          3.0  Cat_4            A
# 2              1.0            Low          1.0  Cat_6            B
# 3              0.0           High          2.0  Cat_6            B
# 4              NaN           High          6.0  Cat_6            A

# %%
dfTr.Age.describe()
# Out:
# count    8068.000000
# mean       43.466906
# std        16.711696
# min        18.000000
# 25%        30.000000
# 50%        40.000000
# 75%        53.000000
# max        89.000000
# Name: Age, dtype: float64

# %%
dfTr[dfTr["Age"]>=40]['Ever_Married'].value_counts()
# Out:
# Yes    3486
# No      699
# Name: Ever_Married, dtype: int64

# %%
dfTr[dfTr["Age"]<40]['Ever_Married'].value_counts()
# Out:
# No     2586
# Yes    1157
# Name: Ever_Married, dtype: int64

# %% [markdown]
# __II. Graduated__

# %%
sns.countplot(dfTr["Graduated"].dropna(), hue = dfTr["Ever_Married"])

# %% [markdown]
# The distribution of customers that have not Graduated is quite even where the Ever_Married is "No". However it's quite significant on the Graduated customers, whereas they are mostly married, with the value twice the customers that are single.
#
# Let's take a look even more.

# %%
plotting("Graduated", "Segmentation", dfTr)

# %% [markdown]
# - The customers that have not Graduated, seems to be occupied by Segmentation D with the value of 17.8%. After that are followed by A, B, C respectively with each values less than 10%.
#
# - The customers that have Graduated, is mostly in Segmentation C with the number of 19.9%. After that are followed by Segmentation B and A, and lastly are Segmentation D.
#
# - From here, we can conclude that most Customers that have Graduated tend to be in Segmentation C, B and A. Whereas those who have not Graduated tend to be in Segmentation D.

# %%
# Change the value of Graduated into number
# X_ will be the final data for the simulating the target (Y)
# For the moment, the null value will be filled with "-1".

X_['Graduated'] = X_['Graduated'].apply(lambda val: 1 if val == 'Yes' else (0 if val == 'No' else -1))
X_.head()
# Out:
#        ID  Gender  Ever_Married  Age  Graduated     Profession  \
# 0  462809    Male             0   22          0     Healthcare
# 1  462643  Female             1   38          1       Engineer
# 2  466315  Female             1   67          1       Engineer
# 3  461735    Male             1   67          1         Lawyer
# 4  462669  Female             1   40          1  Entertainment
#
#    Work_Experience Spending_Score  Family_Size  Var_1 Segmentation
# 0              1.0            Low          4.0  Cat_4            D
# 1              NaN        Average          3.0  Cat_4            A
# 2              1.0            Low          1.0  Cat_6            B
# 3              0.0           High          2.0  Cat_6            B
# 4              NaN           High          6.0  Cat_6            A

# %% [markdown]
# __III. Spending_Score__

# %%
print(dfTr['Spending_Score'].unique())
print(dfTr.Spending_Score.isnull().sum())
# Out:
# ['Low' 'Average' 'High']
# 0

# %%
plotting("Spending_Score", "Segmentation", dfTr)

# %% [markdown]
# #### Comments
#
# - Segmentation D - Spending_Score Low occupies almost 25% of the data. And in S_S Average and High, always ranks the lowest. Therefore, we can conclude that Segmentation D tends to spend the lowest among all Segmentation. Which may be not really profitable towards the automobile company. Needs to target less Segmentation D.
#
# - Segmentation C seems to often spend High or Average. In S_S Average, Segmentation C adds up the most, 11.2%. Whereas in S_S High contributes towards 5% of the data, which is around 800 customers.
#
# - Segmentation B always ranks 2 in Average and High Spending_Score. In S_S high, it is almost similar to Segmentation D, which is 4.8%. Whereas in S_S Average also quite high, which is 7.3%.
#
# - Segmentation A also tends to spend low, contributing to 16.8% of the whole data. However, the amount of customers in Segmentation A who spends high also quite high comparing to the others, which is 3.4%.
#
# - Based on this, the __most profitable__ are in this order: Segmentation C, Segmentation B, Segmentation A, Segmentation D. The model built needs to predict what kind of Customers tend to fall in __Segmentation C and B.__

# %% [markdown]
# Since Spending_Score seems to be the most significant features in the Business Decision, let's evaluate this features further.

# %%
print(dfTr.groupby("Spending_Score")["Graduated"].value_counts())
print("\n")
print(dfTr.groupby("Spending_Score")["Ever_Married"].value_counts())
print("\n")
print(dfTr.groupby("Spending_Score")["Gender"].value_counts())
# Out:
# Spending_Score  Graduated
# Average         Yes          1450
#                 No            503
# High            Yes           780
#                 No            425
# Low             Yes          2738
#                 No           2094
# Name: Graduated, dtype: int64
#
#
# Spending_Score  Ever_Married
# Average         Yes             1937
# High            Yes             1176
# Low             No              3285
#                 Yes             1530
# Name: Ever_Married, dtype: int64
#
#
# Spending_Score  Gender
# Average         Male      1143
#                 Female     831
# High            Male       726
#                 Female     490
# Low             Male      2548
#                 Female    2330
# Name: Gender, dtype: int64

# %% [markdown]
# - From the data above, we can see that customers who have graduated are always higher than the not-graduated customers on every Spending Score. The most significant value can be found in Spending Score Average, with almost 3 times of the customers have graduated. However, in the low Spending Score we can see that it's almost similar with the ratio of the not graduated and graduated around 56%:43%.
#
# - Customers who have never married are mostly distributed in Low Spending Score, which is 41.4% of all the customers. The rest 58.6% of the customers are distributed evenly in all types of Spending Score, with the most fall on Spending Score Average and Low, with the least found in Spending Score High.
#
# - Based on Gender, between Male and Female, Male seems to have more tendency to Spending more in High and average. In the low spending score we can see that both Male and Female are evenly distributed.

# %%
# Label Encoding Spending_Score Column

oneHsp = X_.copy(deep=True).drop('Segmentation', axis=1)
oneHsp['Spending_Score'] = pd.Categorical(oneHsp['Spending_Score'])
dfDummies = pd.get_dummies(oneHsp['Spending_Score'], prefix = 'Spend')
oneHsp_ = pd.concat([oneHsp, dfDummies], axis=1).drop('Spending_Score',
                                                       axis = 1)

# Plotting the Correlation

plt.figure(figsize=(12,8))
plt.title('Correlation Towards Spending Score')
sns.heatmap(oneHsp_.corr(), annot=True)

# %%
oneHsp_.head()
# Out:
#        ID  Gender  Ever_Married  Age  Graduated     Profession  \
# 0  462809    Male             0   22          0     Healthcare
# 1  462643  Female             1   38          1       Engineer
# 2  466315  Female             1   67          1       Engineer
# 3  461735    Male             1   67          1         Lawyer
# 4  462669  Female             1   40          1  Entertainment
#
#    Work_Experience  Family_Size  Var_1  Spend_Average  Spend_High  Spend_Low
# 0              1.0          4.0  Cat_4              0           0          1
# 1              NaN          3.0  Cat_4              1           0          0
# 2              1.0          1.0  Cat_6              0           0          1
# 3              0.0          2.0  Cat_6              0           1          0
# 4              NaN          6.0  Cat_6              0           1          0

# %% [markdown]
# __Comments on Spending_Score__
#
# - Marriage seems to affect most in Spending_Average, the Single Customers tend to spend average or High. The influence is quite high, 43% effects on Spending_Average and 30% on Spending_High.
#
# - Age also plays quite an important role. The older the Age, the more tendency to Spend_High (36%). Whereas the younger the Age, more tendency to Spend_Low (-37%).
#
# - Graduated Customers tend to spend average, but it doesn't impact significantly on High Spending Score. Thus, the degree of customers don't really influence much on the Spending Score.
#
# - Work Experience also doesn't influence much, the more experience the customer has, the more tendency to spend low. However, it's not that much relevant, since the correlation is below 7%.
#
# - Family Size is also quite similar like Work Experience, influencing less than 10%. However, we can see the pattern that the higher the Family Size, the more tendency to Spend Average (9.6%) and High (3.9%). Unfortunately, it's not as impactful as Marriage and Age.

# %%
# Change the value of Spending_Score into number
# Since it is ordinal data, we can use manual Encoder to speed up the model later on

X_2 = X_.copy(deep=True)
X_2['Spending_Score'] = X_['Spending_Score'].apply(lambda val: 2 if val == 'High' else (1 if val == 'Average' else 0))

# Change the value of Gender into number
# Since Male tends to spend more, we label Male as 1 and Female as 0

X_3 = X_2.copy(deep=True)
X_3['Gender'] = X_['Gender'].apply(lambda val: 1 if val == 'Male' else 0)
X_3.head()
# Out:
#        ID  Gender  Ever_Married  Age  Graduated     Profession  \
# 0  462809       1             0   22          0     Healthcare
# 1  462643       0             1   38          1       Engineer
# 2  466315       0             1   67          1       Engineer
# 3  461735       1             1   67          1         Lawyer
# 4  462669       0             1   40          1  Entertainment
#
#    Work_Experience  Spending_Score  Family_Size  Var_1 Segmentation
# 0              1.0               0          4.0  Cat_4            D
# 1              NaN               1          3.0  Cat_4            A
# 2              1.0               0          1.0  Cat_6            B
# 3              0.0               2          2.0  Cat_6            B
# 4              NaN               2          6.0  Cat_6            A

# %%
# Current X information
# Ever_Married, Graduated, Profession, Work_Experience, Family_Size and Var_1 still consisted of Null Values
# Needs to be cleansed later on after analyzation is done

describeDF(X_3)
# Out:
#        dataFeatures dataType  null  nullPct  unique  \
# 0                ID    int64     0     0.00    8068
# 1            Gender    int64     0     0.00       2
# 2      Ever_Married    int64     0     0.00       3
# 3               Age    int64     0     0.00      67
# 4         Graduated    int64     0     0.00       3
# 5        Profession   object   124     1.54       9
# 6   Work_Experience  float64   829    10.28      15
# 7    Spending_Score    int64     0     0.00       3
# 8       Family_Size  float64   335     4.15       9
# 9             Var_1   object    76     0.94       7
# 10     Segmentation   object     0     0.00       4
#
#                                          uniqueSample
# 0            [462809, 462643, 466315, 461735, 462669]
# 1                                              [1, 0]
# 2                                          [0, 1, -1]
# 3                                [22, 38, 67, 40, 56]
# 4                                          [0, 1, -1]
# 5   [Healthcare, Engineer, Lawyer, Entertainment, ...
# 6                           [1.0, nan, 0.0, 4.0, 9.0]
# 7                                           [0, 1, 2]
# 8                           [4.0, 3.0, 1.0, 2.0, 6.0]
# 9                 [Cat_4, Cat_6, Cat_7, Cat_3, Cat_1]
# 10                                       [D, A, B, C]

# %% [markdown]
# __IV. Var_1 Column__
#
# - Var_1 is one of the customer's anonymised features that is confidential, the factor X of the Segmentation. Although we know nothing about what kind of information lies within this category, let's see the distribution and influence towards Customer Segmentation.
#
# - 0.94% of the data obtained for Var_1 contains null values.

# %%
round(dfTr.Var_1.isnull().sum()/len(dfTr.Var_1)*100,2)
# Out:
# 0.94

# %%
dfTr.groupby("Segmentation")["Var_1"].value_counts().unstack()
# Out:
# Var_1         Cat_1  Cat_2  Cat_3  Cat_4  Cat_5  Cat_6  Cat_7
# Segmentation
# A                31     83    223    333     19   1213     51
# B                26    106    186    232     20   1232     43
# C                26     99    154    109     18   1496     47
# D                50    134    259    415     28   1297     62

# %%
df_plot = dfTr.groupby(['Var_1', 'Segmentation']).size().reset_index().pivot(columns='Var_1', index='Segmentation', values=0)
df_plot.plot(kind='bar', stacked=True, figsize=(11,6))

# %%
plotting("Segmentation", "Var_1", dfTr)

# %% [markdown]
# __Conclusion__
#
# - Of all the Segmentations, most customers are in Cat_6. Thus, Cat_6 is the modes in this data.
# - Cat_1 seems to always be the least in every Segmentations.
# - Cat_4 ranks #2 in influencing the Segmentations, except in Segmentation C, where Cat_3 has a little more influence (1.9%) than Cat_4 (1.4%).
# - Cat_2 seems to distribute evenly towards every Segmentations, with the values of 1.0% up to 1.7%.
# - Thus, we can conclude that if the customer tends to have Cat_3 more than Cat_4, it seems that the customer tends to move towards Segmentation C. However, of all the Var_1, the highest tendency still in Cat_6, with the values ranging from 15% up to 18.5% of the users.
# - It is better to use OneHotEncoder to encode this features to avoid confusion of the model later on.

# %% [markdown]
# __V. Profession__
#
# Profession column has 1.54% of null values, and 9 unique values excluding null.

# %%
dfTr.groupby("Segmentation")["Profession"].value_counts().unstack()
# Out:
# Profession    Artist  Doctor  Engineer  Entertainment  Executive  Healthcare  \
# Segmentation
# A                558     199       259            365        125         106
# B                756     143       189            221        183         101
# C               1065     140        75            148        175         146
# D                137     206       176            215        116         979
#
# Profession    Homemaker  Lawyer  Marketing
# Segmentation
# A                    73     197         57
# B                    55     158         30
# C                    28     140         35
# D                    90     128        170

# %%
# Profession Distribution

g = sns.catplot(y="Segmentation", hue="Profession", kind="count",
            palette ="Set2", data=trMod, 
            height=6, aspect=11.7/9)

plt.title('Distribution of Segmentations in Terms of Profession')
plt.xlabel("Frequency")

total = len(trMod["Segmentation"])
for ax in g.axes.ravel():
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.04
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))
plt.grid(True)

# %% [markdown]
# __Comments__
#
# - Segmentation C and B is filled mostly with customers that work as Artist, followed by Entertainment. The difference between Artist and the other Professions are quite significant.
# - In Segmentation C, there are 13.2% of customers that are Artist, whereas the other Profession falls under 2.3% of the population. In Segmentation D also, there are 9.4% that are Artist, and the other falls under 2.8%.
# - The most distinctive difference between Segmentation C and B, is in Segmentation C the #2 of Profession is Executive, followed by Entertainment on #3. Whereas in Segmentation B, the #2 is Entertainment, followed by both Engineer and Executive on #3.
# - The distribution in Segmentation A is quite evenly between Artist, Entertainment, and Engineer with the values of 6.9, 4.5 and 3.2 respectively. The least number is with Marketing and Homemaker, with the value of 0.7 and 0.9.
# - Of all the distribution, Segmentation D seems to have quite distinctive feature. It is mostly occupied by Healthcare (12.1%) followed by Entertainment, Doctor, Engineer, and finally Artist. The healthcare profession has around 6 times of customers compare to the other professions. The least in here is Homemaker.

# %%
# Label Encoding Profession Column

oneHprf = X_3.copy(deep=True).drop('Segmentation', axis=1)
oneHprf['Profession'] = pd.Categorical(oneHsp['Profession'])
dfDummies = pd.get_dummies(oneHprf['Profession'], prefix = 'Profession')
oneHprf_ = pd.concat([oneHprf, dfDummies], axis=1).drop('Profession',
                                                       axis = 1)

# Plotting the Correlation

plt.figure(figsize=(12,8))
plt.title('Correlation Towards Profession')
sns.heatmap(oneHprf_.corr(), annot=True)

# %%
dfTr.groupby("Spending_Score")["Profession"].value_counts().unstack()
# Out:
# Profession      Artist  Doctor  Engineer  Entertainment  Executive  \
# Spending_Score
# Average           1011     177       221            319         75
# High               242      31        60             46        398
# Low               1263     480       418            584        126
#
# Profession      Healthcare  Homemaker  Lawyer  Marketing
# Spending_Score
# Average                 42         60      18         17
# High                    45         26     324         33
# Low                   1245        160     281        242

# %%
dfTr.groupby("Gender")["Profession"].value_counts().unstack()
# Out:
# Profession  Artist  Doctor  Engineer  Entertainment  Executive  Healthcare  \
# Gender
# Female        1213     304       559            253         32         557
# Male          1303     384       140            696        567         775
#
# Profession  Homemaker  Lawyer  Marketing
# Gender
# Female            203     307        164
# Male               43     316        128

# %% [markdown]
# - Executives and Lawyers are dominated with the behaviour of High Spending_Score. The majority of other professions tend to have Low Spending_Score, followed by Average.
# - All professions seem to have the majority of Male gender, except Engineer (559 female 140 male), Homemaker (203 F 43 M) and Marketing (164F 128M)

# %% [markdown]
# __________

# %% [markdown]
# ## 4. Data Preprocessing
#
# In order to simulate data, we first handle the missing values and convert categorical data into number by using Label Encoder/One Hot Encoder.

# %%
dfTr.head()
# Out:
#        ID  Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# 0  462809    Male           No   22        No     Healthcare              1.0
# 1  462643  Female          Yes   38       Yes       Engineer              NaN
# 2  466315  Female          Yes   67       Yes       Engineer              1.0
# 3  461735    Male          Yes   67       Yes         Lawyer              0.0
# 4  462669  Female          Yes   40       Yes  Entertainment              NaN
#
#   Spending_Score  Family_Size  Var_1 Segmentation
# 0            Low          4.0  Cat_4            D
# 1        Average          3.0  Cat_4            A
# 2            Low          1.0  Cat_6            B
# 3           High          2.0  Cat_6            B
# 4           High          6.0  Cat_6            A

# %%
dfNull = describeDF(dfTr)[describeDF(dfTr)['null']>0]
dfNull
# Out:
#       dataFeatures dataType  null  nullPct  unique  \
# 2     Ever_Married   object   140     1.74       2
# 4        Graduated   object    78     0.97       2
# 5       Profession   object   124     1.54       9
# 6  Work_Experience  float64   829    10.28      15
# 8      Family_Size  float64   335     4.15       9
# 9            Var_1   object    76     0.94       7
#
#                                         uniqueSample
# 2                                     [No, Yes, nan]
# 4                                     [No, Yes, nan]
# 5  [Healthcare, Engineer, Lawyer, Entertainment, ...
# 6                          [1.0, nan, 0.0, 4.0, 9.0]
# 8                          [4.0, 3.0, 1.0, 2.0, 6.0]
# 9                [Cat_4, Cat_6, Cat_7, Cat_3, Cat_1]

# %% [markdown]
# ### 4.A. Handling Missing Values

# %% [markdown]
# First, we see the distribution of each columns in terms of Age and create the fill null values method based on the information obtained.
#
# #### i. Overall Distribution

# %%
plt.figure(figsize=(20,12))

plt.subplot(3,2,1)
for i in dfTr['Ever_Married'].unique():
    sns.kdeplot(dfTr[dfTr['Ever_Married']== i]['Age'], legend = False).set_title('Ever_Married Distribution')
    plt.grid(True)

plt.subplot(3,2,2)
for i in dfTr['Graduated'].unique():
    sns.kdeplot(dfTr[dfTr['Graduated']== i]['Age'], legend = False).set_title('Graduated Distribution')
    plt.grid(True)
    
plt.subplot(3,2,3)
for i in dfTr['Profession'].unique():
    sns.kdeplot(dfTr[dfTr['Profession']== i]['Age'], legend = False).set_title('Profession Distribution')
    plt.grid(True)
    
plt.subplot(3,2,4)
for i in dfTr['Work_Experience'].unique():
    sns.kdeplot(dfTr[dfTr['Work_Experience']== i]['Age'], legend = False).set_title('Work_Experience Distribution')
    plt.grid(True)
    
plt.subplot(3,2,5)
for i in dfTr['Family_Size'].unique():
    sns.kdeplot(dfTr[dfTr['Family_Size']== i]['Age'], legend = False).set_title('Family_Size Distribution')
    plt.grid(True)
    
plt.subplot(3,2,6)
for i in dfTr['Var_1'].unique():
    sns.kdeplot(dfTr[dfTr['Var_1']== i]['Age'], legend = False).set_title('Var_1 Distribution')
    plt.grid(True)

# %% [markdown]
# #### Comments:
# 1. As seen from the plots above, all of the data with null is mostly right-skewed. Which means most of the mean, median and mode is in the peak, and located towards negativity.
# 2. The only one that's different is the distribution of Profession, where one of the Profession seems to be highly distributed in Age above 60.
# 3. Thus, we fill the missing values of all the columns beside Profession by auto-fill from Pandas.
# 4. In order to reduce the errors later on, we evaluate by checking how much changed in terms of distribution after filling the null values.

# %%
plt.figure(figsize=(12,8))
for i in dfTr['Profession'].unique():
    sns.kdeplot(dfTr[dfTr['Profession']== i]['Age'], label=i).set_title('Profession Distribution')
    plt.grid(True)
    
dfTr.groupby("Profession")["Age"].describe()
# Out:
#                 count       mean        std   min   25%   50%   75%   max
# Profession
# Artist         2516.0  46.327504  11.969247  18.0  38.0  45.0  53.0  89.0
# Doctor          688.0  37.225291  12.134741  18.0  28.0  35.0  43.0  89.0
# Engineer        699.0  41.745351  12.178982  19.0  32.0  40.0  50.0  81.0
# Entertainment   949.0  43.005269  13.316932  18.0  33.0  41.0  51.0  89.0
# Executive       599.0  51.096828  15.668834  18.0  39.0  50.0  61.0  89.0
# Healthcare     1332.0  26.827327   7.809831  18.0  21.0  26.0  31.0  86.0
# Homemaker       246.0  37.922764  11.969269  20.0  29.0  35.0  43.0  85.0
# Lawyer          623.0  75.215088  10.249553  20.0  70.0  77.0  83.0  89.0
# Marketing       292.0  36.818493  14.054310  18.0  26.0  33.0  45.0  89.0

# %% [markdown]
# - Of all the different professions, customers who work as a lawyer tend to be in the Age above 70. This can be seen from table above, where 25% of the youngest lawyer is 20 years old, but starting from 25% of the distribution it's already in 70 years old.
# - The mean of the lawyers is in 77 years old, where the other Professions have the mean in around 26 up to maximum of 50 years old.

# %% [markdown]
# #### ii. Numerical Columns
#
# Since between all the 6 columns with null value in Work_Experience and Family_Size are numerical we start with this in the first place.

# %%
# Duplicate the statistic distribution of before fillna method
# Rename to avoid confusion

bFillna = dfTr[['Work_Experience', 'Family_Size']].describe(percentiles=[0.25, 0.5, 0.75, 0.8, 0.82, 0.85, 0.9,0.99]).copy().rename(columns= {'Work_Experience': 'Work_Exp_Init', 'Family_Size': 'Fam_Size_Init'})

# Fillna() using "pad" method
dfTr['Work_Experience'] = dfTr['Work_Experience'].fillna(method='pad')
dfTr['Family_Size'] = dfTr['Family_Size'].fillna(method='pad')

a = dfTr.Work_Experience.describe(percentiles=[0.25, 0.5, 0.75, 0.8, 0.82, 0.85, 0.9,0.99])
b = dfTr.Family_Size.describe(percentiles=[0.25, 0.5, 0.75, 0.8, 0.82, 0.85, 0.9,0.99])

# Check the information after fillna
pd.concat([a, b, bFillna], axis=1)
# Out:
#        Work_Experience  Family_Size  Work_Exp_Init  Fam_Size_Init
# count      8068.000000  8068.000000    7239.000000    7733.000000
# mean          2.618741     2.846678       2.641663       2.850123
# std           3.394284     1.530377       3.406763       1.531413
# min           0.000000     1.000000       0.000000       1.000000
# 25%           0.000000     2.000000       0.000000       2.000000
# 50%           1.000000     3.000000       1.000000       3.000000
# 75%           4.000000     4.000000       4.000000       4.000000
# 80%           6.000000     4.000000       6.000000       4.000000
# 82%           7.000000     4.000000       7.000000       4.000000
# 85%           8.000000     4.000000       8.000000       4.000000
# 90%           8.000000     5.000000       8.000000       5.000000
# 99%          13.000000     8.000000      13.000000       8.000000
# max          14.000000     9.000000      14.000000       9.000000

# %% [markdown]
# - After the fillna method, it seems that there is only a slight change in the data.
# - Work_Experience mean is changed by 0.03, where Fam_Size is changed by 0.01 only.
# - Checking from the distribution in terms of percentage, it seems that the fillna method did it quite a justice, so we continue with this.

# %% [markdown]
# #### iii. Categorical Columns
#
# - Except the Profession column, we fill the data using auto fillna.

# %%
# Graduated Column

print("\tGraduated Column Distribution Before Filling Null Values\n")
dfTr.groupby('Graduated')['Age'].describe(percentiles=[0.25, 0.5, 0.75, 0.8, 0.82, 0.85, 0.9,0.99])
# Out:
# 	Graduated Column Distribution Before Filling Null Values
#             count       mean        std   min   25%   50%   75%   80%   82%  \
# Graduated
# No         3022.0  38.376241  18.379691  18.0  23.0  32.0  48.0  53.0  56.0
# Yes        4968.0  46.542271  14.739692  18.0  36.0  43.0  55.0  59.0  60.0
#
#             85%   90%   99%   max
# Graduated
# No         61.0  69.0  87.0  89.0
# Yes        62.0  68.0  87.0  89.0

# %%
# Filling the Graduated Columns Missing Values

dfTr['Graduated'] = dfTr['Graduated'].fillna(method='pad')

# Display the changes after fillna method
print("\tGraduated Column Distribution After Filling Null Values\n")
dfTr.groupby('Graduated')['Age'].describe(percentiles=[0.25, 0.5, 0.75, 0.8, 0.82, 0.85, 0.9,0.99])
# Out:
# 	Graduated Column Distribution After Filling Null Values
#             count       mean        std   min   25%   50%   75%   80%   82%  \
# Graduated
# No         3047.0  38.376764  18.372696  18.0  23.0  32.0  48.0  53.0  56.0
# Yes        5021.0  46.555865  14.788735  18.0  36.0  43.0  55.0  59.0  60.0
#
#             85%   90%   99%   max
# Graduated
# No         61.0  69.0  87.0  89.0
# Yes        62.0  68.0  87.0  89.0

# %%
print("\tEver_Married Column Distribution Before Filling Null Values\n")
dfTr.groupby('Ever_Married')['Age'].describe(percentiles=[0.25, 0.5, 0.75, 0.8, 0.82, 0.85, 0.9,0.99])
# Out:
# 	Ever_Married Column Distribution Before Filling Null Values
#                count       mean        std   min   25%   50%   75%   80%  \
# Ever_Married
# No            3285.0  32.237747  10.767210  18.0  25.0  30.0  38.0  40.0
# Yes           4643.0  51.477278  15.541555  18.0  40.0  49.0  62.0  66.0
#
#                82%   85%   90%   99%   max
# Ever_Married
# No            41.0  42.0  46.0  70.0  89.0
# Yes           67.0  70.0  74.0  88.0  89.0

# %%
# Filling the Graduated Columns Missing Values

dfTr['Ever_Married'] = dfTr['Ever_Married'].fillna(method='pad')

# Display the changes after fillna method
print("\tEver_Married Column Distribution After Filling Null Values\n")
dfTr.groupby('Ever_Married')['Age'].describe(percentiles=[0.25, 0.5, 0.75, 0.8, 0.82, 0.85, 0.9,0.99])
# Out:
# 	Ever_Married Column Distribution After Filling Null Values
#                count       mean        std   min   25%   50%   75%   80%  \
# Ever_Married
# No            3346.0  32.377764  10.991810  18.0  25.0  30.0  38.0  40.0
# Yes           4722.0  51.324651  15.578958  18.0  39.0  49.0  61.0  66.0
#
#                82%   85%   90%    99%   max
# Ever_Married
# No            41.0  42.0  46.0  71.55  89.0
# Yes           67.0  69.0  74.0  88.00  89.0

# %%
print("\t\tDistribution of Var_1 Column Before Fillna")
dfTr.groupby('Var_1')['Age'].describe(percentiles=[0.25, 0.5, 0.75, 0.8, 0.82, 0.85, 0.9,0.99])
# Out:
# 		Distribution of Var_1 Column Before Fillna
#         count       mean        std   min   25%   50%   75%   80%    82%  \
# Var_1
# Cat_1   133.0  39.751880  14.904446  18.0  28.0  38.0  48.0  51.6  55.00
# Cat_2   422.0  37.476303  13.982451  18.0  27.0  36.0  47.0  49.0  50.00
# Cat_3   822.0  39.253041  14.056237  18.0  28.0  38.0  48.0  50.8  52.00
# Cat_4  1089.0  39.108356  14.464244  18.0  28.0  37.0  48.0  51.0  52.00
# Cat_5    85.0  37.164706  13.464987  18.0  26.0  33.0  43.0  48.2  49.88
# Cat_6  5238.0  45.892707  17.414960  18.0  32.0  42.0  57.0  61.0  63.00
# Cat_7   203.0  38.630542  12.811909  18.0  28.0  37.0  48.0  50.0  51.00
#
#         85%   90%    99%   max
# Var_1
# Cat_1  56.2  64.6  73.00  73.0
# Cat_2  51.0  54.8  84.32  89.0
# Cat_3  55.0  59.0  79.00  87.0
# Cat_4  53.0  59.2  80.12  88.0
# Cat_5  52.4  57.6  70.44  78.0
# Cat_6  66.0  72.0  88.00  89.0
# Cat_7  52.7  57.0  68.00  74.0

# %%
# Filling the Graduated Columns Missing Values

dfTr['Var_1'] = dfTr['Var_1'].fillna(method='pad')

# Display the changes after fillna method
print("\tVar_1 Column Distribution After Filling Null Values\n")
dfTr.groupby('Var_1')['Age'].describe(percentiles=[0.25, 0.5, 0.75, 0.8, 0.82, 0.85, 0.9,0.99])
# Out:
# 	Var_1 Column Distribution After Filling Null Values
#         count       mean        std   min    25%   50%   75%   80%    82%  \
# Var_1
# Cat_1   135.0  39.881481  14.831920  18.0  28.50  38.0  48.0  51.2  54.76
# Cat_2   430.0  37.795349  14.417840  18.0  27.00  36.0  47.0  49.0  50.00
# Cat_3   827.0  39.234583  14.033016  18.0  28.00  38.0  48.0  50.0  52.00
# Cat_4  1097.0  39.151322  14.456418  18.0  28.00  37.0  48.0  51.0  52.00
# Cat_5    86.0  37.593023  13.962452  18.0  26.25  33.0  44.5  49.0  50.00
# Cat_6  5287.0  45.857764  17.414083  18.0  32.00  42.0  57.0  61.0  63.00
# Cat_7   206.0  38.718447  12.952760  18.0  28.00  37.0  48.0  50.0  51.00
#
#         85%   90%    99%   max
# Var_1
# Cat_1  56.0  64.2  73.00  73.0
# Cat_2  51.0  57.0  86.71  89.0
# Cat_3  55.0  59.0  79.00  87.0
# Cat_4  53.0  59.0  80.04  88.0
# Cat_5  53.5  59.5  74.60  78.0
# Cat_6  66.0  72.0  88.00  89.0
# Cat_7  53.0  57.0  69.90  74.0

# %%
# dfTr.groupby("Segmentation")["Profession"].value_counts().unstack()

# %%
# dfTr.groupby("Spending_Score")["Profession"].value_counts().unstack()

# %%
# dfTr.groupby("Var_1")["Profession"].value_counts().unstack()

# %% [markdown]
# - Based on the data analysis before, we know some important points such as:
#     1. __Executives and Lawyers__ usually have high spending score, whereas the majority of other professions have low spending score.
#     2. The majority of the professions, except Engineer, Homemaker and Marketing are dominated by Female. Especially __Engineer and Homemaker__ with a very significant difference.
#     3. Most of customers that work as a __Healthcare__ is in Segmentation D.
#     4. Most __Artists__ are in Segmentation B and A.
#     5. Although Segmentation is the target, let's use this as one of the factor to fill the null values here, but with consideration of other features.

# %%
fig = plt.figure(figsize=(18,10))

# Profession vs Ever_Married
ax1 = fig.add_subplot(231)
g = sns.catplot(x="Ever_Married", hue='Profession', kind='count', data=dfTr, ax=ax1)

# Profession vs Graduated
ax2 = fig.add_subplot(232)
g = sns.catplot(x="Graduated", hue='Profession', kind='count', data=dfTr, ax=ax2)

# Profession vs Spending Score
ax3 = fig.add_subplot(233)
g = sns.catplot(x="Spending_Score", hue='Profession', kind='count', data=dfTr, ax=ax3)

# Profession vs Var 1
ax4 = fig.add_subplot(234)
g = sns.catplot(x="Var_1", hue='Profession', kind='count', data=dfTr, ax=ax4)

# Profession vs Gender
ax5 = fig.add_subplot(235)
g = sns.catplot(x="Gender", hue='Profession', kind='count', data=dfTr, ax=ax5)
leg = plt.legend()
ax5.get_legend().remove()

ax6 = fig.add_subplot(236)
g = sns.catplot(x="Segmentation", hue='Profession', kind='count', data=dfTr, ax=ax6)
leg = plt.legend()
ax6.get_legend().remove()

plt.close(2)
plt.close(3)
plt.close(4)
plt.close(5)
plt.close(6)
plt.close(7)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(15,12))

# Profession vs Age
plt.subplot(2,2,1)
for i in dfTr['Profession'].unique():
    sns.kdeplot(dfTr[dfTr['Profession']== i]['Age'], label=i).set_title('Age Distribution')
    plt.grid(True)
    
# Profession vs Work Exp
plt.subplot(2,2,2)
for i in dfTr['Profession'].unique():
    sns.kdeplot(dfTr[dfTr['Profession']== i]['Work_Experience'], label=i).set_title('Work Exp Distribution')
    plt.grid(True)
    
# Profession vs Family Size
plt.subplot(2,2,3)
for i in dfTr['Profession'].unique():
    sns.kdeplot(dfTr[dfTr['Profession']== i]['Family_Size'], label=i).set_title('Family Size Distribution')
    plt.grid(True)

# %% [markdown]
# Some important threshold that can be used to fill missing values:
#
#     1. Married Yes - Artist
#     2. Married No - Healthcare
#     3. Graduated Yes - Artist
#     4. Graduated No - Healthcare
#     5. Age above 70 - Lawyer
#     6. Female - Engineer
#     7. Family Size below 3 - Lawyer
#     8. Family Size above 3 - Healthcare
#     9. Spending Score High - Lawyer and Executives
#     10. Spending Score Low - Healthcare
#     11. Spending Score Average - Artist

# %%
dfTr.isnull().sum()
# Out:
# ID                   0
# Gender               0
# Ever_Married         0
# Age                  0
# Graduated            0
# Profession         124
# Work_Experience      0
# Spending_Score       0
# Family_Size          0
# Var_1                0
# Segmentation         0
# dtype: int64

# %%
# dfBase = df before Profession fillna
dfBase = dfTr.copy(deep=True)

# dfTr = fillna Profession with Threshold

# dfPadProf = df.Prof filled with pad method
dfPadProf = dfTr.copy(deep=True)
dfPadProf['Profession'] = dfPadProf['Profession'].fillna(method='pad')
dfPadProf.Profession.isnull().sum()
# Out:
# 0

# %%
# Filling missing values based on the thresholds

dfTr.loc[ (pd.isnull(dfTr['Profession'])) & (dfTr['Age'] > 68), "Profession"] = 'Lawyer'
dfTr.loc[ (pd.isnull(dfTr['Profession'])) & (dfTr['Spending_Score'] == 'High'), "Profession"] = 'Executive'
dfTr.loc[ (pd.isnull(dfTr['Profession'])) & (dfTr['Work_Experience'] > 6), "Profession"] = 'Homemaker'
dfTr.loc[ (pd.isnull(dfTr['Profession'])) & (dfTr['Ever_Married'] == 'Yes') & (dfTr['Spending_Score'] == 'Average'), "Profession"] = 'Artist'
dfTr.loc[ (pd.isnull(dfTr['Profession'])) & (dfTr['Family_Size'] < 3), "Profession"] = 'Lawyer'
dfTr.loc[ (pd.isnull(dfTr['Profession'])) & (dfTr['Spending_Score'] == 'Low') & (dfTr['Graduated'] == 'No'), "Profession"] = 'Healthcare'
dfTr['Profession'] = dfTr["Profession"].fillna(method='pad')
dfTr.Profession.isnull().sum()
# Out:
# 0

# %%
dfTr.head()
# Out:
#        ID  Gender Ever_Married  Age Graduated     Profession  Work_Experience  \
# 0  462809    Male           No   22        No     Healthcare              1.0
# 1  462643  Female          Yes   38       Yes       Engineer              1.0
# 2  466315  Female          Yes   67       Yes       Engineer              1.0
# 3  461735    Male          Yes   67       Yes         Lawyer              0.0
# 4  462669  Female          Yes   40       Yes  Entertainment              0.0
#
#   Spending_Score  Family_Size  Var_1 Segmentation
# 0            Low          4.0  Cat_4            D
# 1        Average          3.0  Cat_4            A
# 2            Low          1.0  Cat_6            B
# 3           High          2.0  Cat_6            B
# 4           High          6.0  Cat_6            A

# %% [markdown]
# ### 4.b. Preprocessing and Encoding Data

# %%
dfMod = dfTr.copy(deep=True)

# Separating dependent and independent variables
X = dfMod.drop('Segmentation', axis=1)
y = dfMod['Segmentation']

# %%
# Encoding Data

X['Gender'] = X['Gender'].apply(lambda val:1 if val == 'Male' else 0)
X['Ever_Married'] = X['Ever_Married'].apply(lambda val:1 if val == 'Yes' else 0)
X['Graduated'] = X['Graduated'].apply(lambda val:1 if val == 'Yes' else 0)
# X['Spending_Score'] = X['Spending_Score'].apply(lambda val:3 if val == 'High' else (1 if val == 'Low' else 2))

# %%
# Dividing Range numbers into groups
# The division of the group is based on its distribution in terms of percentiles

# Divide Age into Groups
Age_Bin = []
for i, j in zip(X['Age'], range(len(X['Age']))):
    if (i <= 30):
        Age_Bin.append("17-30")
    elif (30 < i <= 45):
        Age_Bin.append("31-45")
    elif (45 < i <= 60):
        Age_Bin.append("46-60")
    else:
        Age_Bin.append("60+")
X['Age_Bin'] = Age_Bin
X.drop('Age', axis=1, inplace=True)
        
# Divide Work Experience into Groups
X['WorkExpCat'] = pd.cut(X.Work_Experience,bins=[-1,1,7,15],labels=['Low','Medium','High'])
X.drop('Work_Experience', axis=1, inplace=True)

# Divide Family Size into Groups
X['FamSizeCat'] = pd.cut(X.Family_Size,bins=[0,4,6,10],labels=['Small','Medium','Big'])
X.drop('Family_Size', axis=1, inplace=True)

# %%
# Encoding the data
# For the numerical data that's divided into groups, we use One Hot Encoder for better model performance 
# Also Spending_Score, since it is an ordinal data

# X.rename(columns={'Spending_Score': 'Spending'}, inplace=True)

# Encoding Age
ag = pd.get_dummies(X.Age_Bin, prefix='AgeBin')
X = pd.concat([X, ag], axis = 1).drop('Age_Bin', axis=1)

# Encoding Work Experience
wr = pd.get_dummies(X.WorkExpCat, prefix='WorkExp')
X = pd.concat([X, wr], axis = 1).drop('WorkExpCat', axis=1)

# Encoding Family Size
fm = pd.get_dummies(X.FamSizeCat, prefix='FamSize')
X = pd.concat([X, fm], axis = 1).drop('FamSizeCat', axis=1)

# Encoding Profession
pr = pd.get_dummies(X.Profession, prefix='Profession')
X = pd.concat([X, pr], axis = 1).drop('Profession', axis=1)

# Encoding Var_1
vr = pd.get_dummies(X.Var_1, prefix='Var_1')
X = pd.concat([X, vr], axis = 1).drop('Var_1', axis=1)

# Encoding Spending Score
sp = pd.get_dummies(X.Spending_Score, prefix='Spending')
X = pd.concat([X, sp], axis = 1).drop('Spending_Score', axis=1)


# Since ID will not affect the simulation, it is dropped to avoid confusion
X.drop('ID', axis=1, inplace=True)
X.columns
# Out:
# Index(['Gender', 'Ever_Married', 'Graduated', 'AgeBin_17-30', 'AgeBin_31-45',
#        'AgeBin_46-60', 'AgeBin_60+', 'WorkExp_Low', 'WorkExp_Medium',
#        'WorkExp_High', 'FamSize_Small', 'FamSize_Medium', 'FamSize_Big',
#        'Profession_Artist', 'Profession_Doctor', 'Profession_Engineer',
#        'Profession_Entertainment', 'Profession_Executive',
#        'Profession_Healthcare', 'Profession_Homemaker', 'Profession_Lawyer',
#        'Profession_Marketing', 'Var_1_Cat_1', 'Var_1_Cat_2', 'Var_1_Cat_3',
#        'Var_1_Cat_4', 'Var_1_Cat_5', 'Var_1_Cat_6', 'Var_1_Cat_7',
#        'Spending_Average', 'Spending_High', 'Spending_Low'],
#       dtype='object')

# %%
# X.head()

# %% [markdown]
# __Correlation of Each Features__

# %%
# plt.figure(figsize=(16,12))
# plt.title('Correlation')
# sns.heatmap(X.corr().round(2), annot=True)

# %%
# y_ = y.copy(deep=True)
# # Replacement based on high to low spending score
# y_ = y_.replace(("C", "B", "A", "D"), (1, 0.66, 0.33, 0))

# dfCorr = pd.concat([X, y_], axis = 1)
# # dfCorr.corr()['Segmentation'].sort_values(ascending=False)

# def correlation_ratio(categories, measurements):
#     fcat, _ = pd.factorize(categories)
#     cat_num = np.max(fcat)+1
#     y_avg_array = np.zeros(cat_num)
#     n_array = np.zeros(cat_num)
#     for i in range(0,cat_num):
#         cat_measures = measurements[np.argwhere(fcat == i).flatten()]
#         n_array[i] = len(cat_measures)
#         y_avg_array[i] = np.average(cat_measures)
#     y_total_avg = np.sum(np.multiply(y_avg_array,n_array))/np.sum(n_array)
#     numerator = np.sum(np.multiply(n_array,np.power(np.subtract(y_avg_array,y_total_avg),2)))
#     denominator = np.sum(np.power(np.subtract(measurements,y_total_avg),2))
#     if numerator == 0:
#         eta = 0.0
#     else:
#         eta = np.sqrt(numerator/denominator)
#     return eta

# lis = []
# for i in dfCorr.drop('Segmentation', axis=1).columns:
#     lis.append([i,correlation_ratio(dfCorr[i], dfCorr['Segmentation'])])
# lis = pd.DataFrame(lis).sort_values(1, ascending=False)

# plt.figure(figsize=(10,10))
# sns.barplot(y=lis[0], x=lis[1])
# plt.title('Correlation Ratio between Segmentation and Other Parameters')
# plt.xlabel('Correlation Value')
# plt.ylabel('Parameter(s)')

# %% [markdown]
# _Observation:_

# %% [markdown]
# ### 4.C. Splitting into train-test data

# %%
# Import the train-test split from library
from sklearn.model_selection import train_test_split

# Divide into train and test sets
# Case 1: 80% Training Data, 20% Test Data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 101)

# Case 2: 70% Training Data, 30% Test Data
X_train2, X_test2, y_train2, y_test2 = train_test_split(X, y, test_size = 0.3, random_state = 101)

# %% [markdown]
# _____

# %% [markdown]
# ## 5. Machine Learning Modeling
#
# ### 5.A. Import Libraries and Base Model Simulation

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, accuracy_score, recall_score, auc, log_loss, roc_auc_score, f1_score, matthews_corrcoef

# %%
def calc_train_error(X_train, y_train, model):
    # return in-sample error for already fit model
    
    predictions = model.predict(X_train)
    predictProba = model.predict_proba(X_train)
    matt = matthews_corrcoef(y_train, predictions)
    f1 = f1_score(y_train, predictions, average='macro')
    classreport = classification_report(y_train, predictions)
    roc_auc = roc_auc_score(y_train, predictProba[:,1])
    accuracy = accuracy_score(y_train, predictions)
    recall = recall_score(y_train, predictions)
    confMatrix = confusion_matrix(y_train, predictions)
    logloss = log_loss(y_train, predictProba)
    return {
        'classreport' : classreport,
        'matthews' : matt,
        'f1' : f1,
        'roc' : roc_auc,
        'accuracy' : accuracy,
        'recall' : recall,
        'confusion' : confMatrix,
        'logloss' : logloss
    }

def calc_validation_error(X_test, y_test, model):
    # return out of sample error for already fit model
    
    predictions = model.predict(X_test)
    predictProba = model.predict_proba(X_test)
    matt = matthews_corrcoef(y_test, predictions)
    f1 = f1_score(y_test, predictions, average='macro')
    classreport = classification_report(y_test, predictions)
    roc_auc = roc_auc_score(y_test, predictProba[:,1])
    accuracy = accuracy_score(y_test, predictions)
    recall = recall_score(y_test, predictions)
    confMatrix = confusion_matrix(y_test, predictions)
    logloss = log_loss(y_test, predictProba)
    return {
        'classreport' : classreport,
        'matthews' : matt,
        'f1' : f1,
        'roc' : roc_auc,
        'accuracy' : accuracy,
        'recall' : recall,
        'confusion' : confMatrix,
        'logloss' : logloss
    }

def calc_metrics(X_train, y_train, X_test, y_test, model):
    # fits model and returns the classification metrics for in sample error and out of sample error
    model.fit(X_train, y_train)
    train_error = calc_train_error(X_train, y_train, model)
    validation_error = calc_validation_error(X_test, y_test, model)
    return train_error, validation_error

# %%
## Decision Tree
print("*************** Decision Tree *************** \n")

print("\nTrain Data\n")
# Fitting train data into model
baseDT = DecisionTreeClassifier(random_state=27, criterion='gini')
baseDT.fit(X_train, y_train)
print('Accuracy Score: ', baseDT.score(X_train, y_train), "\n")

# Predict the target on the train data 
tr_1_DT = baseDT.predict(X_train)
# pp_tr_DT1 = baseDT.predict_proba(X_train)[:, 1]

# Printing report
print('-------------- Train Data Modeling Report --------------\n')
print(classification_report(y_train, tr_1_DT))
print('-------------- Confusion Matrix --------------\n')
print(confusion_matrix(y_train, tr_1_DT))
print('\n')

print("... Fitting into Test Data\n")
# Simulating on Test Data
print("\nTest Data")
print('Accuracy Score: ', baseDT.score(X_test, y_test), "\n")
predDT = baseDT.predict(X_test)
pp_ts_DT1 = baseDT.predict_proba(X_test)[:,1]
print('-------------- Test Data Modeling Report --------------\n')
print(classification_report(y_test, predDT))
print('-------------- Confusion Matrix --------------\n')
print(confusion_matrix(y_test, predDT))
print('\n')
# Out:
# *************** Decision Tree ***************
#
#
# Train Data
#
# Accuracy Score:  0.7136659436008677
#
# -------------- Train Data Modeling Report --------------
#
#               precision    recall  f1-score   support
#
#            A       0.66      0.77      0.71      1582
#            B       0.65      0.56      0.60      1513
#            C       0.70      0.70      0.70      1551
#            D       0.84      0.80      0.82      1808
#
#     accuracy                           0.71      6454
#    macro avg       0.71      0.71      0.71      6454
# weighted avg       0.72      0.71      0.71      6454
#
# -------------- Confusion Matrix --------------
#
# [[1222  132  127  101]
#  [ 279  847  297   90]
#  [ 142  226 1088   95]
#  [ 217   89   53 1449]]
#
#
# ... Fitting into Test Data
#
#
# Test Data
# Accuracy Score:  0.4510532837670384
#
# -------------- Test Data Modeling Report --------------
#
#               precision    recall  f1-score   support
#
#            A       0.36      0.41      0.38       390
#            B       0.28      0.25      0.26       345
#            C       0.50      0.49      0.50       419
#            D       0.61      0.60      0.61       460
#
#     accuracy                           0.45      1614
#    macro avg       0.44      0.44      0.44      1614
# weighted avg       0.45      0.45      0.45      1614
#
# -------------- Confusion Matrix --------------
#
# [[158  81  60  91]
#  [113  85 110  37]
#  [ 69  95 207  48]
#  [100  48  34 278]]

# %%
## Random Forest
print("*************** Random Forest *************** \n")

print("\nTrain Data\n")


# Fitting train data into model
baseRF = RandomForestClassifier(random_state=27, n_estimators=20)
baseRF.fit(X_train, y_train)
print('Accuracy Score: ', baseRF.score(X_train, y_train), "\n")


# Predict the target on the train data 
tr_1_RF = baseRF.predict(X_train)
# Prediction Probability of Train Data
# pp_tr_RF1 = baseRF.predict_proba(X_train)[:, 1]

# Printing report
print('-------------- Train Data Modeling Report --------------\n')
print(classification_report(y_train, tr_1_RF))
print('-------------- Confusion Matrix  --------------\n')
print(confusion_matrix(y_train, tr_1_RF))
print('\n')

print("... Fitting into Test Data\n")

# Simulating on Test Data

print("\nTest Data")
print('Accuracy Score: ', baseRF.score(X_test, y_test), "\n")
predRF = baseRF.predict(X_test)
# Prediction Probability of Test Data
pp_ts_RF1 = baseRF.predict_proba(X_test)[:,1]
print('-------------- Test Data Modeling Report --------------\n')
print(classification_report(y_test, predRF))
print('-------------- Confusion Matrix --------------\n')
print(confusion_matrix(y_test, predRF))
print('\n')
# Out:
# *************** Random Forest ***************
#
#
# Train Data
#
# Accuracy Score:  0.7122714595599628
#
# -------------- Train Data Modeling Report --------------
#
#               precision    recall  f1-score   support
#
#            A       0.70      0.69      0.70      1582
#            B       0.64      0.57      0.60      1513
#            C       0.68      0.73      0.70      1551
#            D       0.80      0.84      0.82      1808
#
#     accuracy                           0.71      6454
#    macro avg       0.71      0.71      0.70      6454
# weighted avg       0.71      0.71      0.71      6454
#
# -------------- Confusion Matrix  --------------
#
# [[1093  189  157  143]
#  [ 205  858  335  115]
#  [  99  207 1126  119]
#  [ 162   81   45 1520]]
#
#
# ... Fitting into Test Data
#
#
# Test Data
# Accuracy Score:  0.4714993804213135
#
# -------------- Test Data Modeling Report --------------
#
#               precision    recall  f1-score   support
#
#            A       0.38      0.38      0.38       390
#            B       0.30      0.28      0.29       345
#            C       0.53      0.52      0.52       419
#            D       0.61      0.65      0.63       460
#
#     accuracy                           0.47      1614
#    macro avg       0.45      0.46      0.46      1614
# weighted avg       0.47      0.47      0.47      1614
#
# -------------- Confusion Matrix --------------
#
# [[147  84  63  96]
#  [ 96  96 107  46]
#  [ 58  96 219  46]
#  [ 86  47  28 299]]

# %% [markdown]
# Comments: Decision Tree may be overfitted with the training data.

# %%
feature_scores = pd.Series(baseRF.feature_importances_, index=X_train.columns).sort_values(ascending=False).head(10)
feature_scores
# Out:
# Gender                   0.083413
# Graduated                0.074533
# Profession_Healthcare    0.071360
# Spending_Low             0.064058
# Profession_Artist        0.060235
# Ever_Married             0.051911
# AgeBin_17-30             0.049592
# Var_1_Cat_6              0.038062
# WorkExp_Low              0.037858
# WorkExp_Medium           0.030499
# dtype: float64

# %%
plt.figure(figsize=(8,7))

coef1 = pd.Series(baseRF.feature_importances_, X.columns).sort_values(ascending=False)
coef1.plot(kind='bar', title='Feature Importances')

# %%
featureEng = ['Gender', 'Graduated', 'Profession_Healthcare', 'Spending_Low', 'Profession_Artist', 'Ever_Married', 'AgeBin_17-30', 'Var_1_Cat_6', 'WorkExp_Low']

data1 = X.copy(deep=True)
data1 = data1[featureEng]
target1 = y.copy(deep=True)

X_tr, X_ts, y_tr, y_ts = train_test_split(data1, target1, test_size = 0.2, random_state = 101)

# Fitting train data into model
rfFeat = RandomForestClassifier(random_state=27, n_estimators=20)
rfFeat.fit(X_tr, y_tr)
print('Accuracy Score: ', rfFeat.score(X_tr, y_tr), "\n")


# Predict the target on the train data 
tr_2_RF = rfFeat.predict(X_tr)
# Prediction Probability of Train Data
# pp_tr_RF1 = baseRF.predict_proba(X_train)[:, 1]

# Printing report
print('-------------- Train Data Modeling Report --------------\n')
print(classification_report(y_tr, tr_2_RF))
print('-------------- Confusion Matrix  --------------\n')
print(confusion_matrix(y_tr, tr_2_RF))
print('\n')

print("... Fitting into Test Data\n")

# Simulating on Test Data

print("\nTest Data")
print('Accuracy Score: ', rfFeat.score(X_ts, y_ts), "\n")
predRF2 = rfFeat.predict(X_ts)
# Prediction Probability of Test Data
pp_ts_RF2 = rfFeat.predict_proba(X_ts)[:,1]
print('-------------- Test Data Modeling Report --------------\n')
print(classification_report(y_ts, predRF2))
print('-------------- Confusion Matrix --------------\n')
print(confusion_matrix(y_ts, predRF2))
print('\n')
# Out:
# Accuracy Score:  0.5441586612953208
#
# -------------- Train Data Modeling Report --------------
#
#               precision    recall  f1-score   support
#
#            A       0.46      0.53      0.49      1582
#            B       0.44      0.34      0.38      1513
#            C       0.56      0.59      0.58      1551
#            D       0.69      0.68      0.68      1808
#
#     accuracy                           0.54      6454
#    macro avg       0.54      0.54      0.53      6454
# weighted avg       0.54      0.54      0.54      6454
#
# -------------- Confusion Matrix  --------------
#
# [[ 844  293  201  244]
#  [ 381  519  461  152]
#  [ 199  271  914  167]
#  [ 418  104   51 1235]]
#
#
# ... Fitting into Test Data
#
#
# Test Data
# Accuracy Score:  0.4795539033457249
#
# -------------- Test Data Modeling Report --------------
#
#               precision    recall  f1-score   support
#
#            A       0.37      0.45      0.41       390
#            B       0.34      0.28      0.30       345
#            C       0.53      0.54      0.54       419
#            D       0.64      0.60      0.62       460
#
#     accuracy                           0.48      1614
#    macro avg       0.47      0.47      0.47      1614
# weighted avg       0.48      0.48      0.48      1614
#
# -------------- Confusion Matrix --------------
#
# [[175  74  66  75]
#  [105  95 117  28]
#  [ 56  83 228  52]
#  [133  31  20 276]]

# %% [markdown]
# ___________

# %% [markdown]
# ### 6. Conclusion and Recommendation for Future Work

# %%
dfConc = pd.read_csv('./Files/Train.csv')

# %%
dfConc.groupby('Spending_Score')['Segmentation'].value_counts()

# for i in dfConc.groupby('Spending_Score')['Segmentation'].value_counts():
#     print(i) #value
# Out:
# Spending_Score  Segmentation
# Average         C                903
#                 B                590
#                 A                343
#                 D                138
# High            C                405
#                 B                384
#                 A                271
#                 D                156
# Low             D               1974
#                 A               1358
#                 B                884
#                 C                662
# Name: Segmentation, dtype: int64

# %%
dfConc.groupby('Var_1')['Spending_Score'].value_counts()
# Out:
# Var_1  Spending_Score
# Cat_1  Low                 86
#        Average             28
#        High                19
# Cat_2  Low                282
#        Average             97
#        High                43
# Cat_3  Low                552
#        Average            197
#        High                73
# Cat_4  Low                672
#        Average            301
#        High               116
# Cat_5  Low                 58
#        Average             20
#        High                 7
# Cat_6  Low               3050
#        Average           1265
#        High               923
# Cat_7  Low                129
#        Average             49
#        High                25
# Name: Spending_Score, dtype: int64

# %%
dfConc['Spending_Score'].value_counts()
# sns.countplot(dfConc['Spending_Score'])
# Out:
# Low        4878
# Average    1974
# High       1216
# Name: Spending_Score, dtype: int64

# %%
# 1974/(4878+1974+1216)
# Out:
# 0.24467030242935053

# %%
# dfConc['Segmentation'].value_counts().loc['D']

# %%
# segPerc = {}
# for i, j in zip(list(dfConc['Segmentation'].value_counts().index), dfConc['Segmentation'].value_counts()):
#     segPerc[i] = j
# print(segPerc)

dfConc['Segmentation'].value_counts(normalize=True).round(3)
# Out:
# D    0.281
# A    0.244
# C    0.244
# B    0.230
# Name: Segmentation, dtype: float64

# %%
dfConc.groupby('Segmentation')['Spending_Score'].value_counts(normalize=True).round(3)
# Out:
# Segmentation  Spending_Score
# A             Low               0.689
#               Average           0.174
#               High              0.137
# B             Low               0.476
#               Average           0.318
#               High              0.207
# C             Average           0.458
#               Low               0.336
#               High              0.206
# D             Low               0.870
#               High              0.069
#               Average           0.061
# Name: Spending_Score, dtype: float64

# %%
# spend = {}
# for i, j in zip(dfConc.groupby('Segmentation')['Spending_Score'].value_counts().index, dfConc.groupby('Segmentation')['Spending_Score'].value_counts()):
#     spend[i] = j
# print(spend)

# %%
dfConc['Segmentation'].value_counts().loc['D']
# Out:
# 2268

# %%
df_plot2 = dfConc.groupby(['Spending_Score', 'Segmentation']).size().reset_index().pivot(columns='Spending_Score', index='Segmentation', values=0)
df_plot2.plot(kind='bar', stacked=True, figsize=(11,6))

# %%
dfConc.shape
# Out:
# (8068, 11)

# %% [markdown]
# __Recap__
#
# 1. Based on the information given, the new market has similar behavior to their previous market, and the sales team segmented the types of customers into 4 types; A, B, C and D.
# 2. Of all the 8068 customers, majority of the segmentation is in Segmentation D, followed by Segmentation A and C in a very similar number and lastly D with a different of around 100 customers.
# 3. Overall, the customers based on Segmentation are fairly distributed, thus, the target data is not imbalanced.
# 4. In all the segmentations, most customers work as Artist, except in Segmentation D which the majority works in Healthcare.
# 5. Although Var_1 is anonymised, it seems that it categorized the types of marketing outreach performed by the sales team, which in turns affecting the customer segmentation.
# 6. In terms of business perspective, it is much profitable if the customers can have a high Spending Score. However, of all the customers it seems that more than half of the customers tend to have Low Spending_Score (61%), whereas Average Spending_Score adds up to 24% and the rest is High Spending_Score.
# 7. If we see from the Spending_Score vs Segmentation barplot, Segmentation C has the least tendency into a Low Spending_Score. 45.8% of the customer in Segmentation C tends to have an Average Spending Score.
# 8. On the other hand, Segmentation D has a more likelihood to have a Low Spending Score, adding up to 87% of the Customers in that Segment.
# 9. Although not as terrible as Segmentation D, Low spending score among those customers contribute to 68.9% of the data.
# 10. Compare to the others, Segmentation B has quite a fairly distributed spending score.
# 11. Thus, for a better economic flow towards the Automobile company, it is highly recommended to engage customers that have more inclination towards Segmentation C and B. It is strongly advised not to engage customers with behavior towards Segmentation D, since it will be terrible for business.

# %%
# Percentage of each profession in each segmentation
# dfConc.groupby('Segmentation')['Profession'].value_counts(normalize=True).round(3)

# Percentage of each spending score in segmentation
# dfConc.groupby('Segmentation')['Spending_Score'].value_counts(normalize=True).round(3)
# dfConc.groupby('Profession')['Spending_Score'].value_counts(normalize=True).round(3)


# Percentage of Var_1 in terms of Segmentation
# dfConc.groupby('Segmentation')['Var_1'].value_counts(normalize=True).round(3)

dfConc.groupby('Segmentation')['Gender'].value_counts(normalize=True).round(3)
# Out:
# Segmentation  Gender
# A             Male      0.539
#               Female    0.461
# B             Male      0.537
#               Female    0.463
# C             Male      0.532
#               Female    0.468
# D             Male      0.577
#               Female    0.423
# Name: Gender, dtype: float64

# %%
# # There are 1970 customer that falls in Segmentation C
# # 1308 customer tends to have high and average spending_Score
# segC = dfConc[(dfConc['Segmentation'] == 'C') & (dfConc['Spending_Score'] != 'Low')]

# # 1974 customers have low spending score out of 2268 customers
# segD = dfConc[(dfConc['Segmentation'] == 'D') & (dfConc['Spending_Score'] == 'Low')]
# # segD

# %% [markdown]
# __Influences of Customers Information Towards Segmentation__
#
# 1. Segmentation C - Lowest Low_Spending_Score Percentage Among Others (33.6% low spending score)
#     Most of the customers that are in Segmentation C, have the following characters:
#     - Most Have graduated.
#     - Works as Artist, Executive, or Entertainment.
#     - Have married but have little family size, mostly 2.
#     - Little work experience. Majority ranging from 0 to 1.
#     - Var_1 is mostly Cat_6, Cat_3 and Cat_4 in order of majority.
#
# 2. Segmentation D - Highest Low_Spending_Score Percentage Among Other Segmentations (87% Low Spending_Score)
#     Most of the customers that are in Segmentation D, have the following characters:
#     - Most Have not graduated.
#     - Mostly Never married. Family Size tends to be high, above 2 and mostly in 5 and 6.
#     - Mostly have a high experience in working. Majority in 7 to 9.
#     - Var_1 is mostly Cat_6, followed by Cat_4 and Cat_3. Similar to other Segmentations.
